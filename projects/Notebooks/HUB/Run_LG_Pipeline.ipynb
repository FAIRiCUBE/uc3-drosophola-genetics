# %% [markdown]
# ## **Landscape Genomics Pipeline**
#
# This Notebook runs a Landscape Genomic Analysis Pipeline on allele frequency data and environmental data.
#
# Default settings are set to run the following analysis:\
# Full set of SNPs data for Drosophila melanogaster (DEST.bio) in European Population samples, analysed with WorldClim BIO1 and Copernicus Near Surface Air Temperature.
#
# **Parameters Required:**
# - Working Directory
# - Subset of Samples
# - Name of Project
# - Data Folder (Contains Environemntal Data and Genomic Data (downlaoded already))

# %%
import sys
sys.path.append('/home/sonjastndl/s3/LGA/uc3-drosophola-genetics/projects/LandscapeGenomicsPipeline/ResourceLogging')

import os
import time
from loguru import logger
from measurer import Measurer
from types import ModuleType

logger.add("logfile.log")
logger.info(f"Processing data for year ")
logger.info("Finished saving data")

data_path = '/'
measurer = Measurer()
tracker = measurer.start(data_path=data_path, logger=logger)
shape = []
# Out:
# 2024-07-15 12:16:02.192 | INFO     | __main__:<module>:11 - Processing data for year
# 2024-07-15 12:16:02.215 | INFO     | __main__:<module>:12 - Finished saving data
# 2024-07-15 12:16:02.216 | INFO     | measurer:start:279 - Started computational costs meter: wall time, memory consumed, network traffic, CO2 emissions, data size

# %%
WorkingDirectory="/home/sonjastndl/s3/LGA/uc3-drosophola-genetics/projects/LandscapeGenomicsPipeline/FULL_PIPELINE"
Continent="Europe"
ProjectName="FullData"
ResourceLogger="/home/sonjastndl/s3/LGA/uc3-drosophola-genetics/projects/LandscapeGenomicsPipeline/ResourceLogging/Resources_PipelineRun_Optimizations3.1.csv"

GenomicData="/home/sonjastndl/s3/LGA/uc3-drosophola-genetics/projects/LandscapeGenomicsPipeline/FULL_PIPELINE/data/PoolSeq2023.vcf.gz"
GenomicMetaData="/home/sonjastndl/s3/LGA/uc3-drosophola-genetics/projects/LandscapeGenomicsPipeline/FULL_PIPELINE/dest_v2.samps_3May2024.csv"
EnvironmentalData="/home/sonjastndl/s3/LGA/uc3-drosophola-genetics/projects/LandscapeGenomicsPipeline/FULL_PIPELINE/data/metadata_new.csv"
GFF="s3/LGA/uc3-drosophola-genetics/projects/LandscapeGenomicsPipeline/FULL_PIPELINE/data/dmel-all-r6.57.gff.gz"

# !bash /home/sonjastndl/s3/LGA/uc3-drosophola-genetics/projects/LandscapeGenomicsPipeline/scripts/Landscape_Genomics.sh $WorkingDirectory $Continent $ProjectName $GenomicData $GenomicMetaData $EnvironmentalData

measurer.end(tracker=tracker,
             shape=shape,
             libraries=[k for k, v in globals().items() if type(v) is ModuleType and not k.startswith('__')],
             data_path=data_path,
             variables=locals(),
             csv_file=ResourceLogger,
            logger=logger)
# Out:
# mkdir: cannot create directory ‘/home/sonjastndl/s3/LGA/uc3-drosophola-genetics/projects/LandscapeGenomicsPipeline/FULL_PIPELINE’: File exists
# mkdir: cannot create directory ‘results’: File exists
# mkdir: cannot create directory ‘data’: File exists
# mkdir: cannot create directory ‘/home/sonjastndl/s3/LGA/uc3-drosophola-genetics/projects/LandscapeGenomicsPipeline/FULL_PIPELINE/results/FullData’: File exists
# mkdir: cannot create directory ‘/home/sonjastndl/s3/LGA/uc3-drosophola-genetics/projects/LandscapeGenomicsPipeline/FULL_PIPELINE/results/FullData/Summary’: File exists
# DOWNLOADING VCF FROM DEST.bio AND EXTRACTING SAMPLENAMES
# DONE
# Starting VCFtools
# Finished VCFtools
# Starting LEA analysis
# mkdir: cannot create directory ‘/home/sonjastndl/s3/LGA/uc3-drosophola-genetics/projects/LandscapeGenomicsPipeline/FULL_PIPELINE/results/FullData/LEA’: File exists
# ...
