# %%
import os
import pandas as pd
from smart_open import smart_open

aws_key = os.environ['S3_FAIRICUBE_STORAGE_KEY']
aws_secret = os.environ['S3_FAIRICUBE_STORAGE_SECRET']

bucket_name = 'fairicube'
object_key = 'genomics_data/raw/filtered/Europe_genomewide_freq.csv'

path = 's3://{}:{}@{}/{}'.format(aws_key, aws_secret, bucket_name, object_key)

df = pd.read_csv(smart_open(path), sep="\t")

# %%
df.describe()
# Out:
#                 POS  AT_Kar_See_1_2016-08-01  AT_Nie_Mau_1_2014-07-20  \
# count  4.832170e+05            483217.000000            483217.000000
# mean   1.423844e+07                 0.108432                 0.111287
# std    7.287027e+06                 0.218601                 0.225039
# min    6.607000e+03                 0.000000                 0.000000
# 25%    8.738784e+06                 0.000000                 0.000000
# 50%    1.412988e+07                 0.000000                 0.000000
# 75%    1.917920e+07                 0.090000                 0.080000
# max    3.207278e+07                 1.000000                 1.000000
#
#        AT_Nie_Mau_1_2014-10-19  AT_Nie_Mau_1_2015-07-20  \
# count            483217.000000            483217.000000
# mean                  0.111216                 0.111867
# std                   0.224692                 0.227939
# min                   0.000000                 0.000000
# ...
